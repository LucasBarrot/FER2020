# %% [markdown]
# Importing Librairies

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import cv2
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.losses import categorical_crossentropy
from keras.optimizers import Adam
from keras.regularizers import l2
from keras.callbacks import ReduceLROnPlateau, TensorBoard, EarlyStopping, ModelCheckpoint
from keras.models import load_model
from keras.models import model_from_json

# %% [markdown]
# Getting data for training

# %%
df = pd.read_csv("train.csv")

width, height = 48, 48

#getting features for training
X = []
for index, row in df.iterrows():
    xx = row['pixels'].split()
    xx = np.asarray(xx).reshape(width, height)
    X.append(xx.astype('float32'))
    
#put in array
X = np.asarray(X)

#build label in one-hot encoding
y = pd.get_dummies(df['emotion']).to_numpy()
print(y[1])
# Out:
# [1 0 0 0 0 0 0]

# %%
print(y[2])
# Out:
# [0 0 1 0 0 0 0]

# %% [markdown]
# Visualising data on picture

# %%
#built label for graph
y_graph =(df['emotion']).to_numpy()

#variables for graph
num_of_samples = []
cols = 5
num_classes = 7

#built graph
fig, axs = plt.subplots(nrows=num_classes, ncols = cols, figsize=(5, 8))
fig.tight_layout()
for i in range(cols):
    for j in range(num_classes):
        x_selected = X[y_graph == j]
        axs[j][i].imshow(x_selected[random.randint(0, len(x_selected - 1)), :, :], cmap=plt.get_cmap("gray"))
        axs[j][i].axis("off")
        if i == 2:
            axs[j][i].set_title(str(j))
            num_of_samples.append(len(x_selected))

#storing them using numpy (useless)
np.save('fdataX', X)
np.save('flabels', y)

print("Preprocessing Done")
print("Number of Features: "+str(len(X[0])))
print("Number of Labels: "+ str(len(y[0])))
print("Number of examples in dataset:"+str(len(X)))
print("X,y stored in fdataX.npy and flabels.npy respectively")
# Out:
# Preprocessing Done
# Number of Features: 48
# Number of Labels: 7
# Number of examples in dataset:35887
# X,y stored in fdataX.npy and flabels.npy respectively

# %% [markdown]
# Preprocessing images

# %%
def preprocess(img):
    img = img/255
    return img

X = np.array(list(map(preprocess, X)))

#create one more dimension to feed in CNN
X = np.expand_dims(X, -1)

# %% [markdown]
# Split data into training set, validating set and testing set

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.1, random_state=41)

# %% [markdown]
# Creating model

# %%
num_features = 64
num_labels = 7
batch_size = 64
epochs = 60

model = Sequential()

model.add(Conv2D(num_features, kernel_size=(3, 3), activation='relu', input_shape=(width, height, 1), data_format='channels_last', kernel_regularizer=l2(0.01)))
model.add(Conv2D(num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(2*2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(2*2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(2*2*2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(2*2*2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.5))

model.add(Flatten())

model.add(Dense(2*2*2*num_features, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(2*2*num_features, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(2*num_features, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(num_labels, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 46, 46, 64)        640
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 46, 46, 64)        36928
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 46, 46, 64)        256
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 23, 23, 64)        0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 23, 23, 64)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 23, 23, 128)       73856
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 23, 23, 128)       512
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 23, 23, 128)       147584
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 23, 23, 128)       512
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 11, 11, 128)       0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 11, 11, 128)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 11, 11, 256)       295168
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 11, 11, 256)       1024
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 11, 11, 256)       590080
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 11, 11, 256)       1024
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 5, 5, 256)         0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 5, 5, 512)         1180160
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 5, 5, 512)         2048
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 5, 5, 512)         2359808
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 5, 5, 512)         2048
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 7)                 903
# =================================================================
# Total params: 5,905,863
# Trainable params: 5,902,151
# Non-trainable params: 3,712
# _________________________________________________________________

# %% [markdown]
# Defining compiling

# %%
model.compile(loss=categorical_crossentropy,
              optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-7),
              metrics=['accuracy'])

# %% [markdown]
# Training model on GPU

# %%
#print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))

#with tf.device('/CPU:0'):
model.fit(np.array(X_train), np.array(y_train),
              batch_size=batch_size,
              epochs=epochs,
              verbose=1,
              validation_data=(np.array(X_valid), np.array(y_valid)),
              shuffle=True)
# Out:
# Epoch 1/60
# 455/455 [==============================] - 410s 901ms/step - loss: 2.0050 - accuracy: 0.2074 - val_loss: 1.8199 - val_accuracy: 0.2594
# Epoch 2/60
# 455/455 [==============================] - 410s 901ms/step - loss: 1.8424 - accuracy: 0.2415 - val_loss: 1.8173 - val_accuracy: 0.2598
# Epoch 3/60
# 455/455 [==============================] - 410s 901ms/step - loss: 1.8228 - accuracy: 0.2494 - val_loss: 1.8030 - val_accuracy: 0.2610
# Epoch 4/60
# 455/455 [==============================] - 409s 900ms/step - loss: 1.8056 - accuracy: 0.2559 - val_loss: 1.7460 - val_accuracy: 0.2632
# Epoch 5/60
# 455/455 [==============================] - 410s 901ms/step - loss: 1.7050 - accuracy: 0.3111 - val_loss: 1.5588 - val_accuracy: 0.3789
# Epoch 6/60
# 455/455 [==============================] - 410s 902ms/step - loss: 1.5753 - accuracy: 0.3794 - val_loss: 1.4937 - val_accuracy: 0.4130
# Epoch 7/60
# 455/455 [==============================] - 410s 902ms/step - loss: 1.4962 - accuracy: 0.4178 - val_loss: 1.4472 - val_accuracy: 0.4368
# Epoch 8/60
# 455/455 [==============================] - 411s 903ms/step - loss: 1.4474 - accuracy: 0.4382 - val_loss: 1.3792 - val_accuracy: 0.4526
# Epoch 9/60
# 455/455 [==============================] - 410s 902ms/step - loss: 1.3963 - accuracy: 0.4624 - val_loss: 1.2926 - val_accuracy: 0.5040
# Epoch 10/60
# 455/455 [==============================] - 410s 902ms/step - loss: 1.3511 - accuracy: 0.4872 - val_loss: 1.3310 - val_accuracy: 0.4901
# Epoch 11/60
# 455/455 [==============================] - 411s 903ms/step - loss: 1.3199 - accuracy: 0.5020 - val_loss: 1.2418 - val_accuracy: 0.5384
# Epoch 12/60
# 455/455 [==============================] - 411s 902ms/step - loss: 1.2868 - accuracy: 0.5150 - val_loss: 1.2422 - val_accuracy: 0.5251
# Epoch 13/60
# 455/455 [==============================] - 411s 902ms/step - loss: 1.2604 - accuracy: 0.5276 - val_loss: 1.1951 - val_accuracy: 0.5399
# Epoch 14/60
# 455/455 [==============================] - 411s 902ms/step - loss: 1.2290 - accuracy: 0.5413 - val_loss: 1.2099 - val_accuracy: 0.5365
# Epoch 15/60
# 455/455 [==============================] - 411s 903ms/step - loss: 1.2025 - accuracy: 0.5547 - val_loss: 1.1410 - val_accuracy: 0.5774
# Epoch 16/60
# 455/455 [==============================] - 410s 901ms/step - loss: 1.1892 - accuracy: 0.5622 - val_loss: 1.1554 - val_accuracy: 0.5715
# Epoch 17/60
# 455/455 [==============================] - 411s 903ms/step - loss: 1.1622 - accuracy: 0.5734 - val_loss: 1.1226 - val_accuracy: 0.5867
# Epoch 18/60
# 455/455 [==============================] - 411s 902ms/step - loss: 1.1299 - accuracy: 0.5862 - val_loss: 1.0749 - val_accuracy: 0.6034
# Epoch 19/60
# 455/455 [==============================] - 411s 903ms/step - loss: 1.1082 - accuracy: 0.5942 - val_loss: 1.0957 - val_accuracy: 0.5991
# Epoch 20/60
# 455/455 [==============================] - 410s 902ms/step - loss: 1.0946 - accuracy: 0.6036 - val_loss: 1.1291 - val_accuracy: 0.5882
# Epoch 21/60
# 455/455 [==============================] - 411s 902ms/step - loss: 1.0674 - accuracy: 0.6125 - val_loss: 1.0393 - val_accuracy: 0.6164
# Epoch 22/60
# 455/455 [==============================] - 414s 909ms/step - loss: 1.0471 - accuracy: 0.6205 - val_loss: 1.1157 - val_accuracy: 0.5867
# Epoch 23/60
# 455/455 [==============================] - 409s 900ms/step - loss: 1.0359 - accuracy: 0.6241 - val_loss: 1.1012 - val_accuracy: 0.5789
# Epoch 24/60
# 455/455 [==============================] - 409s 899ms/step - loss: 1.0027 - accuracy: 0.6360 - val_loss: 1.1005 - val_accuracy: 0.5997
# Epoch 25/60
# 455/455 [==============================] - 409s 898ms/step - loss: 0.9869 - accuracy: 0.6445 - val_loss: 1.1255 - val_accuracy: 0.6003
# Epoch 26/60
# 455/455 [==============================] - 409s 898ms/step - loss: 0.9674 - accuracy: 0.6518 - val_loss: 1.0307 - val_accuracy: 0.6260
# Epoch 27/60
# 455/455 [==============================] - 410s 900ms/step - loss: 0.9500 - accuracy: 0.6593 - val_loss: 1.0153 - val_accuracy: 0.6368
# Epoch 28/60
# 455/455 [==============================] - 410s 900ms/step - loss: 0.9265 - accuracy: 0.6667 - val_loss: 1.0506 - val_accuracy: 0.6232
# Epoch 29/60
# 455/455 [==============================] - 409s 900ms/step - loss: 0.9081 - accuracy: 0.6733 - val_loss: 1.0758 - val_accuracy: 0.5994
# Epoch 30/60
# 455/455 [==============================] - 409s 900ms/step - loss: 0.8940 - accuracy: 0.6760 - val_loss: 1.0568 - val_accuracy: 0.6269
# Epoch 31/60
# 455/455 [==============================] - 409s 899ms/step - loss: 0.8796 - accuracy: 0.6811 - val_loss: 1.0156 - val_accuracy: 0.6350
# Epoch 32/60
# 455/455 [==============================] - 409s 900ms/step - loss: 0.8557 - accuracy: 0.6883 - val_loss: 1.0421 - val_accuracy: 0.6375
# Epoch 33/60
# 455/455 [==============================] - 409s 899ms/step - loss: 0.8401 - accuracy: 0.6964 - val_loss: 1.0711 - val_accuracy: 0.6353
# Epoch 34/60
# 455/455 [==============================] - 409s 899ms/step - loss: 0.8329 - accuracy: 0.7020 - val_loss: 1.1695 - val_accuracy: 0.5954
# Epoch 35/60
# 455/455 [==============================] - 409s 899ms/step - loss: 0.7998 - accuracy: 0.7145 - val_loss: 1.1041 - val_accuracy: 0.6241
# Epoch 36/60
# 455/455 [==============================] - 409s 899ms/step - loss: 0.8020 - accuracy: 0.7140 - val_loss: 1.0433 - val_accuracy: 0.6433
# Epoch 37/60
# 455/455 [==============================] - 409s 899ms/step - loss: 0.7746 - accuracy: 0.7216 - val_loss: 1.1006 - val_accuracy: 0.6322
# Epoch 38/60
# 455/455 [==============================] - 409s 899ms/step - loss: 0.7646 - accuracy: 0.7282 - val_loss: 1.1013 - val_accuracy: 0.6183
# Epoch 39/60
# 455/455 [==============================] - 409s 898ms/step - loss: 0.7585 - accuracy: 0.7316 - val_loss: 1.0723 - val_accuracy: 0.6446
# Epoch 40/60
# 455/455 [==============================] - 409s 898ms/step - loss: 0.7388 - accuracy: 0.7383 - val_loss: 1.0126 - val_accuracy: 0.6467
# Epoch 41/60
# 455/455 [==============================] - 409s 898ms/step - loss: 0.7201 - accuracy: 0.7435 - val_loss: 1.4315 - val_accuracy: 0.5307
# Epoch 42/60
# 455/455 [==============================] - 409s 899ms/step - loss: 0.7153 - accuracy: 0.7481 - val_loss: 1.0608 - val_accuracy: 0.6449
# Epoch 43/60
# 455/455 [==============================] - 409s 898ms/step - loss: 0.6885 - accuracy: 0.7586 - val_loss: 1.0565 - val_accuracy: 0.6511
# Epoch 44/60
# 455/455 [==============================] - 408s 897ms/step - loss: 0.6866 - accuracy: 0.7581 - val_loss: 1.0470 - val_accuracy: 0.6396
# Epoch 45/60
# 455/455 [==============================] - 409s 898ms/step - loss: 0.6763 - accuracy: 0.7649 - val_loss: 1.1086 - val_accuracy: 0.6313
# Epoch 46/60
# 455/455 [==============================] - 408s 897ms/step - loss: 0.6539 - accuracy: 0.7699 - val_loss: 1.0149 - val_accuracy: 0.6526
# Epoch 47/60
# 455/455 [==============================] - 409s 898ms/step - loss: 0.6450 - accuracy: 0.7750 - val_loss: 1.0932 - val_accuracy: 0.6452
# Epoch 48/60
# 455/455 [==============================] - 409s 899ms/step - loss: 0.6380 - accuracy: 0.7796 - val_loss: 1.1080 - val_accuracy: 0.6464
# Epoch 49/60
# 455/455 [==============================] - 409s 898ms/step - loss: 0.6217 - accuracy: 0.7827 - val_loss: 1.0324 - val_accuracy: 0.6545
# Epoch 50/60
# 455/455 [==============================] - 409s 898ms/step - loss: 0.6174 - accuracy: 0.7861 - val_loss: 1.2082 - val_accuracy: 0.6359
# Epoch 51/60
# 455/455 [==============================] - 408s 897ms/step - loss: 0.6041 - accuracy: 0.7909 - val_loss: 1.0882 - val_accuracy: 0.6613
# Epoch 52/60
# 455/455 [==============================] - 409s 898ms/step - loss: 0.5877 - accuracy: 0.7982 - val_loss: 1.2074 - val_accuracy: 0.6477
# Epoch 53/60
# 455/455 [==============================] - 409s 899ms/step - loss: 0.5799 - accuracy: 0.7997 - val_loss: 1.1017 - val_accuracy: 0.6471
# Epoch 54/60
# 455/455 [==============================] - 410s 901ms/step - loss: 0.5688 - accuracy: 0.8061 - val_loss: 1.0993 - val_accuracy: 0.6554
# Epoch 55/60
# 455/455 [==============================] - 406s 892ms/step - loss: 0.5555 - accuracy: 0.8066 - val_loss: 1.1216 - val_accuracy: 0.6545
# Epoch 56/60
# 455/455 [==============================] - 406s 893ms/step - loss: 0.5466 - accuracy: 0.8138 - val_loss: 1.1030 - val_accuracy: 0.6607
# Epoch 57/60
# 455/455 [==============================] - 406s 893ms/step - loss: 0.5498 - accuracy: 0.8122 - val_loss: 1.1856 - val_accuracy: 0.6576
# Epoch 58/60
# 455/455 [==============================] - 406s 892ms/step - loss: 0.5287 - accuracy: 0.8192 - val_loss: 1.1662 - val_accuracy: 0.6607
# Epoch 59/60
# 455/455 [==============================] - 407s 894ms/step - loss: 0.5250 - accuracy: 0.8208 - val_loss: 1.1639 - val_accuracy: 0.6628
# Epoch 60/60
# 455/455 [==============================] - 406s 892ms/step - loss: 0.5125 - accuracy: 0.8265 - val_loss: 1.1609 - val_accuracy: 0.6492

# %% [markdown]
# Saving model

# %%
fer_json = model.to_json()
with open("fer.json", "w") as json_file:
    json_file.write(fer_json)
model.save_weights("fer.h5")

# %% [markdown]
# Loading model

# %%
json_file = open('fer.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("fer.h5")
print("Loaded model from disk")

#with tf.device('/CPU:0'):
predict = loaded_model.predict_classes((X_test[30]).reshape(1, 48, 48, 1))
print(predict)
# Out:
# Loaded model from disk
# [3]

# %%
plt.imshow(X_test[30].reshape(48, 48))
print(np.argmax(y_test[30]))
# Out:
# 3

# %% [markdown]
# Printing score

# %%
#with tf.device('/CPU:0'):
loaded_model.compile(loss=categorical_crossentropy,
                  optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-7),
                  metrics=['accuracy'])
score = loaded_model.evaluate(np.array(X_test), np.array(y_test), verbose=0)
print(score)
# Out:
# [1.2029898166656494, 0.6352744698524475]
